# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# Through data analysis and visualization, we can attempt to answer questions about our data and about the metric that we have created

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
games = pd.read_csv('../games.csv')
playerData = pd.read_csv('../players.csv')
tackleData = pd.read_csv('../tackles.csv')
plays = pd.read_csv("../plays.csv")

# %%
plays
# Out:
#            gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0      2022100908    3537          48723           Parker Hesse
# 1      2022091103    3126          52457         Chase Claypool
# 2      2022091111    1148          42547          Darren Waller
# 3      2022100212    2007          46461             Mike Boone
# 4      2022091900    1372          47857       Devin Singletary
# ...           ...     ...            ...                    ...
# 12481  2022100204     123          43293        Ezekiel Elliott
# 12482  2022091200    3467          46189            Will Dissly
# 12483  2022101605    3371          44860              Joe Mixon
# 12484  2022100207    2777          52449        Jonathan Taylor
# 12485  2022102308     905          54572          Dameon Pierce
#
#                                          playDescription  quarter  down  \
# 0      (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# ...

# %%
totaltracking = []

for i in range(9):
    string = '../tracking_week_' + str(i + 1) + '.csv'
    track = pd.read_csv(string)
    totaltracking.append(track)
    
trackingdata = pd.concat(totaltracking, axis=0, ignore_index=True)

# %%
trackingdata
# Out:
#               gameId  playId    nflId     displayName  frameId  \
# 0         2022090800      56  35472.0  Rodger Saffold        1
# 1         2022090800      56  35472.0  Rodger Saffold        2
# 2         2022090800      56  35472.0  Rodger Saffold        3
# 3         2022090800      56  35472.0  Rodger Saffold        4
# 4         2022090800      56  35472.0  Rodger Saffold        5
# ...              ...     ...      ...             ...      ...
# 12187393  2022110700    3787      NaN        football       40
# 12187394  2022110700    3787      NaN        football       41
# 12187395  2022110700    3787      NaN        football       42
# 12187396  2022110700    3787      NaN        football       43
# 12187397  2022110700    3787      NaN        football       44
#
#                                 time  jerseyNumber      club playDirection  \
# 0         2022-09-08 20:24:05.200000          76.0       BUF          left
# ...

# %% [markdown]
# # Plotting Clutchness of Players on a Team vs. Overall Team Record

# %% [markdown]
# One way to validate the usefullness of our metric is to compare it with other meaningful stats.  In the NFL, there is probably no more meaningful stat than wins.  We can see if there is a correlation between the average clutchness of defensive players on a team, and the team's overall record.

# %% [markdown]
# The two seem to be strongly correlated (SHOW THIS USING SIMILARITY thing from exercise).  However, correlation does not mean causation.  Whether clutch players produce winning teams or winning teams produce clutch players is a borderline philosophical question across all sports

# %% [markdown]
# # Plotting Clutchness of Players by Position

# %% [markdown]
# We notice that there tend to be more clutch players in certain positions.  If we remove the distance travelled by the tackler, the correlation is a lot less strong.

# %% [markdown]
# # Plotting Clutchness of Players vs Jersey Sales

# %% [markdown]
# This visualization is more for fun than it is practical.  We wanted to see if clutch players sell more jerseys.  There is no clear correlation
