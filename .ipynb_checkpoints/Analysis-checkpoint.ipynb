# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# Through data analysis and visualization, we can attempt to answer questions about our data and about the metric that we have created

# %% [markdown]
# ### Loading in the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
games = pd.read_csv('../games.csv')
playerData = pd.read_csv('../players.csv')
tackleData = pd.read_csv('../tackles.csv')
plays = pd.read_csv("../plays.csv")

# %%
totaltracking = []

for i in range(9):
    string = '../tracking_week_' + str(i + 1) + '.csv'
    track = pd.read_csv(string)
    totaltracking.append(track)
    
trackingdata = pd.concat(totaltracking, axis=0, ignore_index=True)

# %%
#Concrete Stats for each tackle

ball_carrier = pd.DataFrame(plays.loc[:, ['playId', 'ballCarrierId', 'gameId', 'down', 'yardsToGo']])
ball_carrier['timeLeft'] = ((4 - plays['quarter']) * 15 + plays['gameClock'].str[:-3].astype(int)).astype(str) + plays['gameClock'].str[-3:]
ball_carrier['scoreDif'] = plays['preSnapHomeScore'].sub(plays['preSnapVisitorScore'])
ball_carrier['endZoneDistance'] = 100 - plays['absoluteYardlineNumber'] - plays['playResult']
ball_carrier['yardsto1st'] = plays['yardsToGo'] - plays['playResult']
ball_carrier['defensiveTeam'] = plays['defensiveTeam']
tackler = pd.DataFrame(tackleData.loc[:, ['playId', 'nflId', 'gameId']])
name = pd.DataFrame(playerData.loc[:, ['nflId', 'displayName']])

tackle_stats = pd.merge(ball_carrier, tackler, on=('playId', 'gameId'))
tackle_stats = pd.merge(tackle_stats, name, on='nflId')

tackle_stats
# Out:
#        playId  ballCarrierId      gameId  down  yardsToGo timeLeft  scoreDif  \
# 0        3537          48723  2022100908     1         10     7:52        14
# 1          84          47853  2022110609     2         10    59:50         0
# 2        1016          53555  2022102301     1         10    41:29         0
# 3         879          52460  2022110609     3          1    45:58         3
# 4          97          46155  2022102700     1         10    59:18         0
# ...       ...            ...         ...   ...        ...      ...       ...
# 17421    3790          54556  2022101607     4          1     5:10         8
# 17422    1945          53549  2022100905     2         10    26:45        16
# 17423    3201          47807  2022110604     2         10     7:24         4
# 17424     779          53454  2022103000     2          2    47:42         7
# 17425    2514          47911  2022100912     1         10    17:46        -9
#
#        endZoneDistance  yardsto1st defensiveTeam  nflId         displayName
# 0                   22           1            TB  43306          Keanu Neal
# 1                   12           5            TB  43306          Keanu Neal
# 2                   31           1            TB  43306          Keanu Neal
# 3                    6          -1            TB  43306          Keanu Neal
# 4                   42           5            TB  43306          Keanu Neal
# ...                ...         ...           ...    ...                 ...
# 17421                1          -1           PIT  52904        Elijah Riley
# 17422               72          11           DET  55030    Demetrius Taylor
# 17423               14           7           JAX  48508      Andrew Wingard
# 17424               29           0           DEN  48308     Jonathan Kongbo
# 17425              -11           4            LA  44838  Takkarist McKinley
#
# [17426 rows x 12 columns]

# %%
# Add clutch stat to dataframe

tackle_stats['clutchness'] = tackle_stats[['down', 'yardsToGo', 'scoreDif', 'yardsto1st', 'endZoneDistance']].mean(axis=1)

tackle_stats
# Out:
#        playId  ballCarrierId      gameId  down  yardsToGo timeLeft  scoreDif  \
# 0        3537          48723  2022100908     1         10     7:52        14
# 1          84          47853  2022110609     2         10    59:50         0
# 2        1016          53555  2022102301     1         10    41:29         0
# 3         879          52460  2022110609     3          1    45:58         3
# 4          97          46155  2022102700     1         10    59:18         0
# ...       ...            ...         ...   ...        ...      ...       ...
# 17421    3790          54556  2022101607     4          1     5:10         8
# 17422    1945          53549  2022100905     2         10    26:45        16
# 17423    3201          47807  2022110604     2         10     7:24         4
# 17424     779          53454  2022103000     2          2    47:42         7
# 17425    2514          47911  2022100912     1         10    17:46        -9
#
#        endZoneDistance  yardsto1st defensiveTeam  nflId         displayName  \
# 0                   22           1            TB  43306          Keanu Neal
# 1                   12           5            TB  43306          Keanu Neal
# 2                   31           1            TB  43306          Keanu Neal
# 3                    6          -1            TB  43306          Keanu Neal
# 4                   42           5            TB  43306          Keanu Neal
# ...                ...         ...           ...    ...                 ...
# 17421                1          -1           PIT  52904        Elijah Riley
# 17422               72          11           DET  55030    Demetrius Taylor
# 17423               14           7           JAX  48508      Andrew Wingard
# 17424               29           0           DEN  48308     Jonathan Kongbo
# 17425              -11           4            LA  44838  Takkarist McKinley
#
#        clutchness
# 0             9.6
# 1             5.8
# 2             8.6
# 3             2.4
# 4            11.6
# ...           ...
# 17421         2.6
# 17422        22.2
# 17423         7.4
# 17424         8.0
# 17425        -1.0
#
# [17426 rows x 13 columns]

# %%
# Create new dataframe that contains the averages of the tackle stats
# for each unique player in displayName_x

averages_df = tackle_stats.groupby('displayName')[['down', 'yardsToGo', 'scoreDif', 'yardsto1st', 'endZoneDistance', 'clutchness']].mean().reset_index()
averages_df['team'] = tackle_stats.groupby('displayName')['defensiveTeam'].first().reset_index()['defensiveTeam']
averages_df = averages_df.round({'down': 2, 'yardsToGo': 2, 'scoreDif': 2, 'yardsto1st': 2, 'endZoneDistance': 2, 'clutchness': 2})

averages_df
# Out:
#           displayName  down  yardsToGo  scoreDif  yardsto1st  endZoneDistance  \
# 0    A'Shawn Robinson  1.50       8.03     -3.08        4.67            36.83
# 1        A.J. Epenesa  1.43      10.00     12.86        4.29            36.86
# 2          A.J. Klein  1.33       7.17      2.00        2.17            57.50
# 3         A.J. Parker  2.17       9.25     10.00       -1.50            29.33
# 4        A.J. Terrell  1.71       7.57      6.77       -1.94            27.71
# ..                ...   ...        ...       ...         ...              ...
# 794         Zack Baun  1.67      10.00    -12.00        6.67            52.33
# 795    Zaire Franklin  1.64       8.53      1.63        1.80            33.77
# 796     Zaven Collins  1.71       8.13      0.30        1.08            36.70
# 797   Zech McPhearson  2.00       7.50    -22.00      -11.50            25.00
# 798     Zyon McCollum  1.69       8.62      3.15       -5.92            18.92
#
#      clutchness team
# 0          9.59   LA
# 1         13.09  BUF
# 2         14.03  BAL
# 3          9.85  DET
# 4          8.37  ATL
# ..          ...  ...
# 794       11.73   NO
# 795        9.47  IND
# 796        9.58  ARI
# 797        0.20  PHI
# 798        5.29   TB
#
# [799 rows x 8 columns]

# %%
# Creating data frame with team winning percentage

pct = { 'team': ['LA', 'BUF', 'BAL', 'DET', 'ATL', 'NYG', 'JAX', 'GB', 'NE', 'PIT', 'NYJ', 'MIN', 'CIN', 'SF',
                    'TB', 'SEA', 'CHI', 'DEN', 'CLE', 'LAC', 'NO', 'TEN', 'CAR', 'LV', 'MIA', 'DAL', 'ARI', 'PHI',
                    'IND', 'WAS', 'HOU', 'KC'],
           'winningPct': [.294, .813, .588, .529, .412, .559, .529, .471, .471, .529, .412, .765, .750, .765,
                         .471, .529, .176, .294, .412, .588, .412, .412, .412, .353, .529, .706, .235, .824,
                         .265, .500, .206, .824] }

pct = pd.DataFrame(data=records)

# adding winning pct to player tackle stats dataframe

averages_df = pd.merge(averages_df, pct, on='team')

averages_df
# Out:
#            displayName  down  yardsToGo  scoreDif  yardsto1st  \
# 0     A'Shawn Robinson  1.50       8.03     -3.08        4.67
# 1         Aaron Donald  1.73       8.00     -0.90        5.87
# 2         Bobby Wagner  1.91       7.83      0.09        3.33
# 3         Cobie Durant  2.00       9.00     10.00        1.00
# 4      Derion Kendrick  1.71       9.07     -2.43       -2.50
# ..                 ...   ...        ...       ...         ...
# 794      Rashad Fenton  1.85       7.81     -6.23       -3.12
# 795  Taylor Stallworth  1.00       6.00      2.00        4.00
# 796   Tershawn Wharton  2.50      10.75     -6.00        5.25
# 797     Trent McDuffie  1.50      11.00     -2.00      -13.00
# 798         Willie Gay  1.68       8.32     -4.97        2.53
#
#      endZoneDistance  clutchness team  winningPct
# 0              36.83        9.59   LA       0.294
# 1              33.43        9.63   LA       0.294
# 2              31.03        8.84   LA       0.294
# 3               4.50        5.30   LA       0.294
# 4              26.25        6.42   LA       0.294
# ..               ...         ...  ...         ...
# 794            27.85        5.63   KC       0.824
# 795            75.50       17.70   KC       0.824
# 796            23.00        7.10   KC       0.824
# 797            12.50        2.00   KC       0.824
# 798            36.68        8.85   KC       0.824
#
# [799 rows x 9 columns]

# %% [markdown]
# # Plotting Clutchness of Players on a Team vs. Overall Team Record

# %%
plt.scatter(averages_df['clutchness'], averages_df['winningPct'])
plt.xlabel('clutchness')
plt.ylabel('winningPct')
# Out:
# Text(0, 0.5, 'winningPct')

# %% [markdown]
# # Plotting Clutchness of Players vs Position

# %% [markdown]
# We notice that there tend to be more clutch players in certain positions.  If we remove the distance travelled by the tackler, the correlation is a lot less strong.

# %% [markdown]
# # Plotting Clutchness of Players vs Jersey Sales

# %% [markdown]
# This visualization is more for fun than it is practical.  We wanted to see if clutch players sell more jerseys.  There is no clear correlation
